# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanushAnbalagan/Stock_Trend_Prediction/blob/main/Stock_Trend_Pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as data

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
# !pip install pandas_datareader

# %%
# !pip install yfinance

# %%
import yfinance as yf
import datetime as dt

stock = "ADANIPOWER.NS"
start = dt.datetime(2000, 1, 1)
end = dt.datetime(2024, 11, 1)

df = yf.download(stock, start, end)
# Out:
# /tmp/ipython-input-4-3982881395.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock, start, end)
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
# Price              Close          High           Low          Open  \
# Ticker     ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS
# Date
# 2009-08-20    100.099998    110.000000     98.300003    108.000000
# 2009-08-21    103.150002    103.900002     98.000000     99.900002
# 2009-08-24    103.099998    104.400002    101.550003    103.900002
# 2009-08-25    102.750000    103.150002    101.000000    102.500000
# 2009-08-26    105.099998    107.500000    102.849998    103.000000
#
# Price             Volume
# Ticker     ADANIPOWER.NS
# Date
# 2009-08-20     164328256
# 2009-08-21      33717840
# 2009-08-24      13665282
# 2009-08-25      11720267
# 2009-08-26      17158838

# %%
df.tail()
# Out:
# Price              Close          High           Low          Open  \
# Ticker     ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS
# Date
# 2024-10-25    592.299988    612.299988    585.099976    605.700012
# 2024-10-28    598.200012    606.700012    572.650024    586.099976
# 2024-10-29    592.299988    596.099976    578.299988    579.950012
# 2024-10-30    592.049988    599.799988    584.049988    595.000000
# 2024-10-31    592.700012    609.900024    590.000000    601.000000
#
# Price             Volume
# Ticker     ADANIPOWER.NS
# Date
# 2024-10-25       2432785
# 2024-10-28       3684210
# 2024-10-29       2649607
# 2024-10-30       1808791
# 2024-10-31       2434391

# %%
df.shape
# Out:
# (3749, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3749 entries, 2009-08-20 to 2024-10-31
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   (Close, ADANIPOWER.NS)   3749 non-null   float64
#  1   (High, ADANIPOWER.NS)    3749 non-null   float64
#  2   (Low, ADANIPOWER.NS)     3749 non-null   float64
#  3   (Open, ADANIPOWER.NS)    3749 non-null   float64
#  4   (Volume, ADANIPOWER.NS)  3749 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 175.7 KB

# %%
df.isnull().sum()
# Out:
# Price   Ticker
# Close   ADANIPOWER.NS    0
# High    ADANIPOWER.NS    0
# Low     ADANIPOWER.NS    0
# Open    ADANIPOWER.NS    0
# Volume  ADANIPOWER.NS    0
# dtype: int64

# %%
df.describe()
# Out:
# Price          Close          High           Low          Open        Volume
# Ticker ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS
# count    3749.000000   3749.000000   3749.000000   3749.000000  3.749000e+03
# mean      119.564084    122.099960    117.259322    119.811977  9.336346e+06
# std       152.169722    155.273625    149.390235    152.619938  1.533398e+07
# min        15.450000     16.100000     15.150000     15.450000  0.000000e+00
# 25%        35.799999     36.500000     35.099998     35.900002  2.080077e+06
# 50%        55.700001     57.099998     54.500000     55.950001  4.772765e+06
# 75%       115.550003    117.449997    114.000000    115.300003  1.069290e+07
# max       874.500000    895.849976    826.650024    873.000000  2.421999e+08

# %%
df = df.reset_index()
df.head()
# Out:
# Price        Date         Close          High           Low          Open  \
# Ticker            ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS
# 0      2009-08-20    100.099998    110.000000     98.300003    108.000000
# 1      2009-08-21    103.150002    103.900002     98.000000     99.900002
# 2      2009-08-24    103.099998    104.400002    101.550003    103.900002
# 3      2009-08-25    102.750000    103.150002    101.000000    102.500000
# 4      2009-08-26    105.099998    107.500000    102.849998    103.000000
#
# Price         Volume
# Ticker ADANIPOWER.NS
# 0          164328256
# 1           33717840
# 2           13665282
# 3           11720267
# 4           17158838

# %%
df.shape
# Out:
# (3749, 6)

# %%
df.to_csv("adanipower.csv")

# %%
df1 = pd.read_csv("/content/adanipower.csv")

# %%
df1.head()
# Out:
#     Price        Date              Close               High  \
# 0  Ticker         NaN      ADANIPOWER.NS      ADANIPOWER.NS
# 1       0  2009-08-20  100.0999984741211              110.0
# 2       1  2009-08-21  103.1500015258789  103.9000015258789
# 3       2  2009-08-24  103.0999984741211  104.4000015258789
# 4       3  2009-08-25             102.75  103.1500015258789
#
#                   Low               Open         Volume
# 0       ADANIPOWER.NS      ADANIPOWER.NS  ADANIPOWER.NS
# 1   98.30000305175781              108.0      164328256
# 2                98.0   99.9000015258789       33717840
# 3  101.55000305175781  103.9000015258789       13665282
# 4               101.0              102.5       11720267

# %%
#Creating Candlesticks
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x = df1['Date'], open = df1['Open'], high = df1['High'],
                                 low = df1['Low'], close = df1['Close'])])
fig.update_layout(xaxis_rangeslider_visible=False) #Hides the range slider
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#As now we dont need the Date, adj close columns we can DROP it
df = df.drop(['Date'], axis = 1)
# Out:
# /tmp/ipython-input-23-2470342604.py:2: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
df.head()
# Out:
# Price          Close          High           Low          Open        Volume
# Ticker ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS ADANIPOWER.NS
# 0         100.099998    110.000000     98.300003    108.000000     164328256
# 1         103.150002    103.900002     98.000000     99.900002      33717840
# 2         103.099998    104.400002    101.550003    103.900002      13665282
# 3         102.750000    103.150002    101.000000    102.500000      11720267
# 4         105.099998    107.500000    102.849998    103.000000      17158838

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Close'], label = f'{stock} Closing Price', linewidth = 1)
plt.title(f'{stock} Closing Price over time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Open'], label = f'{stock} Opening Price', linewidth = 1)
plt.title(f'{stock} Opening Price over time')
plt.xlabel('Date')
plt.ylabel('Opening Price (USD)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['High'], label = f'{stock} High Price', linewidth = 1)
plt.title(f'{stock} High Price over time')
plt.xlabel('Date')
plt.ylabel('High Price (USD)')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Volume'], label = f'{stock} Volume Price', linewidth = 1)
plt.title(f'{stock} Volume Price over time')
plt.xlabel('Date')
plt.ylabel('Volume Price (USD)')
plt.legend()
plt.show()

# %% [markdown]
# There are 2 types in Stock Market techiniqes 1.MOVING AVG 2.EXPONENTIAL MOVING **AVG**

# %%
#Moving Average
# [10, 20, 30, 40, 50, 60, 70, 80, 90]
# Moving average for Last 5 days

temp_data = [10, 20, 30, 40, 50, 60, 70, 80, 90]
print(sum(temp_data[2:7])/5)
# Out:
# 50.0

# %%
import pandas as pd
df01 = pd.DataFrame(temp_data)

# %%
#We can use the "rolling technique" to find the moving object
df01.rolling(5).mean()
# Out:
#       0
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4  30.0
# 5  40.0
# 6  50.0
# 7  60.0
# 8  70.0

# %%
ma100 = df.Close.rolling(100).mean()

# %%
ma100
# Out:
# Ticker  ADANIPOWER.NS
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 3744         682.7755
# 3745         681.5280
# 3746         680.1845
# 3747         678.6115
# 3748         676.8680
#
# [3749 rows x 1 columns]

# %%
ma200 = df.Close.rolling(200).mean()

# %%
#Lets visulise the moving avg
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ma100, label = f'{stock} Moving Avg 100 Price', linewidth = 1)
plt.plot(ma200, label = f'{stock} Moving Avg 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
#To calculate the exponential moving avg
ema100 = df.Close.ewm(span=100, adjust = False).mean()

# %%
ema200 = df['Close'].ewm(span=200, adjust = False).mean()

# %%
#Lets visulise the moving avg
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label = f'{stock} Close Price', linewidth = 1)
plt.plot(ema100, label = f'{stock} Exp.Moving Avg 100 Price', linewidth = 1)
plt.plot(ema200, label = f'{stock} Exp.Moving Avg 200 Price', linewidth = 1)
plt.legend()
plt.show()

# %%
#Divide the Data into Training and Testing

data_training = pd.DataFrame(df['Close'][0:int(len(df)*0.70)])  #70% of the data
data_testing = pd.DataFrame(df['Close'][int(len(df)*0.70): int(len(df))])

# %%
data_training.shape
# Out:
# (2624, 1)

# %%
data_testing.shape
# Out:
# (1125, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (0, 1))

# %%
data_training_array = scaler.fit_transform(data_training)

# %%
data_training_array
# Out:
# array([[0.66184515],
#        [0.68569193],
#        [0.68530097],
#        ...,
#        [0.11258796],
#        [0.12079749],
#        [0.15089913]])

# %%
data_training_array.shape[0]
# Out:
# 2624

# %%
import numpy as np

# %%
x_train = []
y_train = []

for i in range(100, data_training_array.shape[0]):
    x_train.append(data_training_array[i-100:i])
    y_train.append(data_training_array[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train.shape
# Out:
# (2524, 100, 1)

# %%
#Model Building
from keras.layers import Dense, Dropout, LSTM
from keras.models import Sequential

# %% [markdown]
# LSTM of 2types-2D & 3D. 2D->(batch_size, units), 3D->(batch_size, time_steps, units)

# %%
model = Sequential()

model.add(LSTM(units = 50, activation = 'relu', return_sequences = True, input_shape = (x_train.shape[1],1)))
model.add(Dropout(0.2))

model.add(LSTM(units = 60, activation = 'relu', return_sequences = True))
model.add(Dropout(0.3))

model.add(LSTM(units = 80, activation = 'relu', return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 120, activation = 'relu'))
model.add(Dropout(0.4))

model.add(Dense(units = 1))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                   │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ...

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
model.fit(x_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 20s 107ms/step - loss: 0.0538
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0059
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0060
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0048
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0044
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0040
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.0037
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 0.0035
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0039
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - loss: 0.0033
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0032
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0030
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0036
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 0.0028
# ...

# %%
past_100_days = data_training.tail(100)

# %%
 final_df = pd.concat([past_100_days, data_testing], ignore_index = True)

# %%
 final_df.head()
# Out:
# Ticker  ADANIPOWER.NS
# 0           60.500000
# 1           62.400002
# 2           61.849998
# 3           61.700001
# 4           61.549999

# %%
input_data = scaler.fit_transform(final_df)

# %%
x_test = []
y_test = []

for i in range(100, input_data.shape[0]):
    x_test.append(input_data[i-100:i])
    y_test.append(input_data[i, 0])

x_test, y_test = np.array(x_test), np.array(y_test)

# %%
x_test.shape
# Out:
# (1125, 100, 1)

# %%
y_predicted = model.predict(x_test)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step

# %%
y_predicted.shape
# Out:
# (1125, 1)

# %%
scaler.scale_
# Out:
# array([0.00117806])

# %%
scaler_factor = 1 / 0.00117806
y_predicted = y_predicted * scaler_factor
y_test = y_test * scaler_factor

# %%
#Lets visulise the moving avg
plt.figure(figsize=(12, 6))
plt.plot(y_test, label = 'Original Price', linewidth = 1)
plt.plot(y_predicted, label = 'Predicted Price', linewidth = 1)
plt.legend()
plt.show()

# %%
model.save('stock_dl_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
